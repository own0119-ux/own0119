# %% [markdown]
# <a href="https://colab.research.google.com/github/own0119-ux/own0119/blob/%EC%88%99%EC%A0%9C/%EC%A7%91%ED%95%A9_%ED%81%B4%EB%9E%98%EC%8A%A4_%EC%98%88%EC%A0%9C(%EC%A4%91%EB%B3%B5%ED%8F%B4%EB%8D%94).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
폴더1 ={"1","2","3","4"}
폴더2 ={"3","4","5","6"}

# %%
class 폴더합치기:
    def __init__(self,폴더_1,폴더_2):
        self.폴더1 = 폴더_1
        self.폴더2 = 폴더_2

    def 중복폴더(self):
        중복 = self.폴더1 & self.폴더2
        print("중복 폴더" + str(중복))

# %%
경고 = 폴더합치기(폴더1,폴더2)
경고.중복폴더()
# Out:
# 중복 폴더{'3', '4'}
